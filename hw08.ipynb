# %%
Ixx = 1/12*(C^2+B^2)
Iyy = 1/12*(C^2+A^2)
Izz = 1/12*(A^2+B^2)

IT = [[Ixx, 0, 0],
      [0, Iyy, 0],
      [0, 0, Izz]]

Ri = [[0, -C/2, B/2],
      [C/2, 0, -A/2],
      [-B/2, A/2, 0]]

IT - mRi^2
